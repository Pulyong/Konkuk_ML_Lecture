# %%
from google.colab import drive
drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
import numpy as np
import torch

# 데이터 읽기 함수
def load_dataset(file):

  data = np.loadtxt(file)
  print("DATA=",data)
  
  x = data[:,0:-1]
  print("X=",x)
  
  y = np.reshape(data[:,-1],(3,1))
  print("Y=",y)
 
  # 텐서로 변경
  x = torch.tensor(x, dtype = torch.float)
  y = torch.tensor(y, dtype = torch.float)
  # 이곳을 채우세요.

  return (x, y)

# 텐서를 리스트로 바꾸는 함수
def tensor2list(input_tensor):
  return input_tensor.cpu().detach().numpy().tolist()

x, y = load_dataset("/gdrive/Othercomputers/내 컴퓨터/Konkuk_ML/week2/train.txt")

# 가중치 초기화
w = torch.randn(1)*3.0
print("\nInit: w = {0}\n".format(tensor2list(w)))

# 학습률
alpha = 0.1

# 학습데이터 수
m = y.size(0)

for epoch in range(50):

  cost = 0

  for i in range(m):
    # 이곳을 채우세요.
    cost += (w * x[i] - y[i]) * x[i]
  # 이곳을 채우세요.
  cost = cost / m
  w = w - alpha * cost
  print("Epoch {0:d}: w = {1}".format(epoch+1,tensor2list(w)))
# Out:
# DATA= [[1. 1.]
#  [2. 2.]
#  [3. 3.]]
# X= [[1.]
#  [2.]
#  [3.]]
# Y= [[1.]
#  [2.]
#  [3.]]
#
# Init: w = [-1.42121160030365]
#
# Epoch 1: w = [-0.29131269454956055]
# Epoch 2: w = [0.31129997968673706]
# Epoch 3: w = [0.6326932907104492]
# Epoch 4: w = [0.8041030764579773]
# Epoch 5: w = [0.8955216407775879]
# Epoch 6: w = [0.9442781805992126]
# Epoch 7: w = [0.970281720161438]
# Epoch 8: w = [0.984150230884552]
# Epoch 9: w = [0.9915468096733093]
# Epoch 10: w = [0.995491623878479]
# Epoch 11: w = [0.9975955486297607]
# Epoch 12: w = [0.9987176060676575]
# Epoch 13: w = [0.9993160367012024]
# Epoch 14: w = [0.9996352195739746]
# Epoch 15: w = [0.9998054504394531]
# Epoch 16: w = [0.999896228313446]
# Epoch 17: w = [0.9999446868896484]
# Epoch 18: w = [0.9999704957008362]
# Epoch 19: w = [0.9999842643737793]
# Epoch 20: w = [0.9999915957450867]
# Epoch 21: w = [0.9999955296516418]
# Epoch 22: w = [0.999997615814209]
# Epoch 23: w = [0.9999987483024597]
# Epoch 24: w = [0.9999993443489075]
# Epoch 25: w = [0.9999996423721313]
# Epoch 26: w = [0.9999998211860657]
# Epoch 27: w = [0.9999998807907104]
# Epoch 28: w = [0.9999999403953552]
# Epoch 29: w = [1.0]
# Epoch 30: w = [1.0]
# Epoch 31: w = [1.0]
# Epoch 32: w = [1.0]
# Epoch 33: w = [1.0]
# Epoch 34: w = [1.0]
# Epoch 35: w = [1.0]
# Epoch 36: w = [1.0]
# Epoch 37: w = [1.0]
# Epoch 38: w = [1.0]
# Epoch 39: w = [1.0]
# Epoch 40: w = [1.0]
# Epoch 41: w = [1.0]
# Epoch 42: w = [1.0]
# Epoch 43: w = [1.0]
# Epoch 44: w = [1.0]
# Epoch 45: w = [1.0]
# Epoch 46: w = [1.0]
# Epoch 47: w = [1.0]
# Epoch 48: w = [1.0]
# Epoch 49: w = [1.0]
# Epoch 50: w = [1.0]
